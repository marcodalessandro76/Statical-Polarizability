# %% [markdown]
# # Create tables from the HG data

# %% [markdown]
# This nb is written in python3 to use tabulate. The nb has to be run WITHOUT the source of the BigDFT package, otherwise the import yaml gives rise to a conflict.

# %%
import yaml
import numpy as np
from tabulate import tabulate
AuToA = 0.5291772085**3

# %%
HG_data=yaml.load(open('../HG Dataset/hg_data.yaml'))

# %%
HG_data['CO']
# Out:
# {'CCSD(T)': [1.753, 1.753, 2.283],
#  'field_int': 0.01,
#  'lda-SPW92': [1.872, 1.872, 2.358],
#  'lda-Slater': [1.993, 1.993, 2.49],
#  'mpol_ref': '1',
#  'pbe': [1.856, 1.856, 2.363],
#  'pbe0': [1.778, 1.778, 2.274],
#  'spin_pol': 'nsp'}

# %%
molecule_nsp = []
molecule_sp = []
for mol in HG_data:
    if HG_data[mol]['spin_pol'] == 'nsp' : molecule_nsp.append(mol)
    if HG_data[mol]['spin_pol'] == 'sp' : molecule_sp.append(mol)
molecule_nsp = sorted(molecule_nsp)
molecule_sp = sorted(molecule_sp)

# %%
print(len(molecule_nsp),len(molecule_sp))
# Out:
# 75 57

# %%
table_nsp = [[] for line in range(len(molecule_nsp)+1)]
table_sp = [[] for line in range(len(molecule_sp)+1)]

# %%
table_nsp[0] = ['molecule','lda','pbe','pbe0','field_int']
table_sp[0] = ['molecule','lda','pbe','pbe0','field_int']

# %%
def format_decimal(ll):
    out = [ '%.2f' % elem for elem in ll ]
    out = [float(elem) for elem in out]
    return out

for ind,mol in enumerate(molecule_nsp):
    lda_ref = list(np.array(HG_data[mol]['lda-SPW92'])/AuToA)
    pbe_ref = list(np.array(HG_data[mol]['pbe'])/AuToA)
    pbe0_ref = list(np.array(HG_data[mol]['pbe0'])/AuToA)
    f_int = HG_data[mol]['field_int']
    table_nsp[ind+1] = [mol,format_decimal(lda_ref),\
                        format_decimal(pbe_ref),format_decimal(pbe0_ref),f_int]

for ind,mol in enumerate(molecule_sp):
    lda_ref = list(np.array(HG_data[mol]['lda-SPW92'])/AuToA)
    pbe_ref = list(np.array(HG_data[mol]['pbe'])/AuToA)
    pbe0_ref = list(np.array(HG_data[mol]['pbe0'])/AuToA)
    f_int = HG_data[mol]['field_int']
    table_sp[ind+1] = [mol,format_decimal(lda_ref),\
                        format_decimal(pbe_ref),format_decimal(pbe0_ref),f_int]

# %%
print(tabulate(table_nsp, tablefmt="latex"))
# Out:
# \begin{tabular}{lllll}
# \hline
#  molecule & lda                     & pbe                      & pbe0                     & field\_int \\
#  AlF      & [41.53, 41.53, 37.72]   & [42.46, 42.46, 38.17]    & [42.16, 42.16, 36.29]    & 0.01      \\
#  Ar       & [12.01, 12.01, 12.01]   & [11.94, 11.94, 11.94]    & [11.42, 11.42, 11.42]    & 0.01      \\
#  BF       & [22.37, 22.37, 20.18]   & [22.07, 22.07, 20.07]    & [21.32, 21.32, 18.76]    & 0.01      \\
#  BH2Cl    & [25.54, 29.36, 40.27]   & [25.26, 29.03, 39.77]    & [24.48, 28.01, 37.94]    & 0.01      \\
#  BH2F     & [15.42, 19.72, 19.5]    & [15.21, 19.47, 19.3]     & [14.54, 18.54, 18.17]    & 0.01      \\
#  BH3      & [20.28, 20.28, 15.48]   & [19.85, 19.85, 15.13]    & [19.14, 19.14, 14.65]    & 0.01      \\
#  BHF2     & [15.24, 19.54, 18.77]   & [15.14, 19.43, 18.71]    & [14.27, 18.02, 17.44]    & 0.01      \\
#  BeH2     & [22.11, 22.11, 22.24]   & [21.57, 21.57, 21.72]    & [20.64, 20.64, 20.83]    & 0.01      \\
#  C2H2     & [20.08, 20.08, 32.01]   & [20.12, 20.12, 31.99]    & [19.51, 19.51, 31.46]    & 0.01      \\
#  C2H4     & [23.49, 26.65, 36.52]   & [23.43, 26.41, 36.37]    & [22.83, 25.62, 35.92]    & 0.01      \\
#  CH2BH    & [30.1, 26.04, 40.99]    & [30.22, 25.79, 40.83]    & [29.18, 25.0, 39.92]     & 0.01      \\
#  CH3BH2   & [26.86, 36.9, 31.04]    & [26.4, 36.15, 30.54]     & [25.56, 34.23, 29.5]     & 0.01      \\
#  CH3Cl    & [28.52, 28.52, 38.65]   & [28.24, 28.24, 38.38]    & [27.18, 27.18, 37.2]     & 0.01      \\
#  CH3F     & [17.51, 17.51, 18.76]   & [17.34, 17.34, 18.69]    & [16.52, 16.52, 17.71]    & 0.01      \\
#  CH3NH2   & [30.46, 26.87, 25.39]   & [30.23, 26.58, 25.13]    & [28.61, 24.96, 24.17]    & 0.01      \\
#  CH3OH    & [21.84, 25.02, 21.61]   & [21.64, 24.91, 21.41]    & [20.7, 23.54, 20.21]     & 0.01      \\
#  CH3SH    & [45.39, 36.0, 36.46]    & [44.99, 35.6, 36.06]     & [43.53, 34.4, 34.55]     & 0.01      \\
#  CH4      & [17.79, 17.79, 17.79]   & [17.48, 17.48, 17.48]    & [16.86, 16.86, 16.86]    & 0.01      \\
#  CO       & [12.63, 12.63, 15.91]   & [12.52, 12.52, 15.95]    & [12.0, 12.0, 15.35]      & 0.01      \\
#  CO2      & [13.33, 13.33, 26.77]   & [13.38, 13.38, 26.76]    & [12.82, 12.82, 25.79]    & 0.01      \\
#  CS       & [24.69, 24.69, 39.17]   & [24.53, 24.53, 39.11]    & [23.98, 23.98, 37.9]     & 0.01      \\
#  CSO      & [26.52, 26.52, 51.89]   & [26.51, 26.51, 51.83]    & [25.81, 25.81, 50.79]    & 0.01      \\
#  Cl2      & [26.53, 26.53, 43.04]   & [26.37, 26.37, 42.94]    & [25.29, 25.29, 42.12]    & 0.01      \\
#  ClCN     & [23.98, 23.98, 48.17]   & [23.92, 23.92, 48.15]    & [23.19, 23.19, 46.21]    & 0.01      \\
#  ClF      & [17.4, 17.4, 23.08]     & [17.36, 17.36, 23.15]    & [16.45, 16.45, 22.6]     & 0.01      \\
#  FCN      & [15.49, 15.49, 26.72]   & [15.53, 15.53, 26.78]    & [14.95, 14.95, 25.6]     & 0.01      \\
#  FNO      & [23.69, 17.33, 12.51]   & [23.79, 17.41, 12.48]    & [22.76, 16.47, 11.82]    & 0.01      \\
#  H        & [6.09, 6.09, 6.09]      & [5.59, 5.59, 5.59]       & [5.23, 5.23, 5.23]       & 0.01      \\
#  H2       & [5.29, 5.29, 7.19]      & [5.07, 5.07, 6.94]       & [4.89, 4.89, 6.73]       & 0.01      \\
#  H2O      & [10.66, 10.61, 10.61]   & [10.66, 10.61, 10.55]    & [9.53, 10.02, 9.74]      & 0.01      \\
#  HBO      & [15.16, 15.16, 22.24]   & [15.16, 15.16, 22.24]    & [14.5, 14.5, 21.27]      & 0.01      \\
#  HBS      & [29.92, 29.92, 46.25]   & [29.81, 29.81, 46.08]    & [29.16, 29.16, 45.09]    & 0.01      \\
#  HCCCl    & [28.52, 28.52, 59.84]   & [28.47, 28.47, 59.72]    & [27.61, 27.61, 57.69]    & 0.01      \\
#  HCCF     & [20.1, 20.1, 34.54]     & [20.2, 20.2, 34.57]      & [19.44, 19.44, 33.34]    & 0.01      \\
#  HCHO     & [13.72, 19.8, 23.76]    & [13.64, 19.71, 23.71]    & [13.16, 18.4, 22.59]     & 0.01      \\
#  HCN      & [14.77, 14.77, 23.32]   & [14.75, 14.75, 23.4]     & [14.29, 14.29, 22.81]    & 0.01      \\
#  HCONH2   & [37.78, 30.68, 21.28]   & [37.82, 30.66, 21.21]    & [34.9, 28.2, 20.08]      & 0.01      \\
#  HCOOH    & [28.86, 26.55, 17.35]   & [28.9, 26.55, 17.3]      & [27.05, 24.44, 16.38]    & 0.01      \\
#  HCl      & [18.21, 18.21, 19.41]   & [18.07, 18.07, 19.25]    & [17.22, 17.22, 18.65]    & 0.01      \\
#  HF       & [5.93, 5.93, 6.85]      & [5.95, 5.95, 6.89]       & [5.38, 5.38, 6.45]       & 0.01      \\
#  HNC      & [16.59, 16.59, 24.45]   & [16.44, 16.44, 24.56]    & [15.78, 15.78, 23.48]    & 0.01      \\
#  HOCl     & [21.37, 20.63, 29.34]   & [21.3, 20.56, 29.38]     & [20.28, 19.37, 28.67]    & 0.01      \\
#  HOOH     & [14.62, 19.39, 13.87]   & [14.64, 19.53, 13.87]    & [13.69, 19.18, 12.69]    & 0.01      \\
#  He       & [1.65, 1.65, 1.65]      & [1.58, 1.58, 1.58]       & [1.49, 1.49, 1.49]       & 0.01      \\
#  LiBH4    & [32.55, 32.55, 35.81]   & [31.78, 31.78, 35.08]    & [30.21, 30.21, 32.97]    & 0.01      \\
#  LiCN     & [28.36, 28.07, 23.15]   & [28.84, 28.32, 23.19]    & [25.81, 26.44, 21.6]     & 0.01      \\
#  LiCl     & [29.09, 29.09, 31.08]   & [29.1, 29.1, 31.24]      & [26.7, 26.7, 28.32]      & 0.01      \\
#  LiH      & [35.06, 35.06, 32.58]   & [34.09, 34.09, 32.31]    & [30.41, 30.41, 27.28]    & 0.001     \\
#  Mg       & [71.4, 71.4, 71.4]      & [74.16, 74.16, 74.16]    & [75.11, 75.11, 75.11]    & 0.001     \\
#  Mg2      & [122.95, 122.95, 232.2] & [127.11, 127.11, 241.96] & [128.62, 128.62, 241.31] & 0.001     \\
#  N2       & [10.74, 10.74, 15.37]   & [10.68, 10.68, 15.43]    & [10.29, 10.29, 15.09]    & 0.01      \\
#  N2H4     & [22.69, 27.45, 23.73]   & [22.57, 27.43, 23.59]    & [21.36, 25.83, 21.77]    & 0.01      \\
#  NH2Cl    & [24.97, 25.07, 35.29]   & [24.83, 24.92, 35.26]    & [23.66, 23.64, 34.26]    & 0.01      \\
#  NH2F     & [15.52, 17.14, 15.2]    & [15.51, 17.19, 15.18]    & [14.43, 16.45, 14.21]    & 0.01      \\
#  NH2OH    & [19.71, 23.11, 18.22]   & [19.66, 23.18, 18.16]    & [18.22, 22.19, 16.97]    & 0.01      \\
#  NH3      & [14.62, 14.62, 17.58]   & [14.52, 14.52, 17.44]    & [13.77, 13.77, 15.68]    & 0.01      \\
#  NH3O     & [20.76, 20.76, 30.28]   & [20.85, 20.85, 30.38]    & [18.67, 18.67, 26.41]    & 0.01      \\
#  NaCN     & [34.21, 33.59, 25.99]   & [35.02, 34.56, 26.1]     & [31.24, 29.38, 23.94]    & 0.01      \\
#  NaCl     & [33.09, 33.09, 44.9]    & [33.13, 33.13, 46.6]     & [29.93, 29.93, 37.94]    & 0.001     \\
#  NaH      & [42.7, 42.7, 65.39]     & [41.41, 41.41, 62.84]    & [37.83, 37.83, 53.39]    & 0.001     \\
#  Ne       & [3.05, 3.05, 3.05]      & [3.07, 3.07, 3.07]       & [2.81, 2.81, 2.81]       & 0.01      \\
#  OCl2     & [30.79, 57.66, 33.0]    & [30.66, 57.51, 32.86]    & [29.11, 54.08, 31.66]    & 0.01      \\
#  P2H4     & [52.83, 76.77, 53.28]   & [52.02, 76.01, 52.45]    & [50.71, 73.74, 50.98]    & 0.01      \\
#  PH2OH    & [35.64, 35.92, 35.49]   & [35.19, 35.78, 35.04]    & [33.8, 34.08, 33.66]     & 0.01      \\
#  PH3      & [31.76, 31.76, 34.23]   & [31.22, 31.22, 33.55]    & [30.44, 30.44, 32.25]    & 0.01      \\
#  PH3O     & [29.9, 29.9, 35.91]     & [29.5, 29.5, 35.55]      & [28.17, 28.17, 33.45]    & 0.01      \\
#  S2H2     & [40.68, 59.16, 40.47]   & [40.27, 58.79, 40.06]    & [38.85, 56.97, 38.65]    & 0.01      \\
#  SCl2     & [40.26, 72.25, 49.87]   & [40.01, 71.84, 49.65]    & [38.35, 68.95, 48.11]    & 0.01      \\
#  SF2      & [24.14, 27.22, 24.87]   & [24.19, 27.3, 24.96]     & [22.5, 25.99, 23.69]     & 0.01      \\
#  SH2      & [27.29, 25.67, 25.87]   & [27.01, 25.36, 25.52]    & [25.59, 24.65, 24.65]    & 0.01      \\
#  SO2      & [20.36, 34.4, 24.08]    & [20.37, 34.56, 24.17]    & [19.61, 33.28, 22.86]    & 0.01      \\
#  SiH3Cl   & [41.44, 41.44, 52.58]   & [40.66, 40.66, 51.72]    & [39.21, 39.21, 49.59]    & 0.01      \\
#  SiH3F    & [31.62, 31.62, 28.66]   & [30.91, 30.91, 28.26]    & [29.56, 29.56, 26.88]    & 0.01      \\
#  SiH4     & [34.15, 34.15, 34.15]   & [33.18, 33.18, 33.18]    & [31.99, 31.99, 31.99]    & 0.01      \\
#  SiO      & [28.22, 28.22, 35.59]   & [28.5, 28.5, 35.87]      & [27.67, 27.67, 33.83]    & 0.01      \\
# \hline
# \end{tabular}
